# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemasaiprasanna/FMML_ASSIGNMENT_AND_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-01 15:21:39--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   142MB/s    in 0.5s
#
# 2024-04-01 15:21:40 (142 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15106   1403.4928v1  We describe the Clinical TempEval task which i...    cs
# 12981   1005.4717v4  We study the problem of estimating high-dimens...  stat
# 7995   1709.07626v1  Recurrent neural networks (RNNs) have shown pr...    cs
# 12133  1709.01972v3  The Whitney embedding theorem gives an upper b...  stat
# 29233  1708.08016v1  We have developed a convolutional neural netwo...    cs
# ...             ...                                                ...   ...
# 14916   1303.2449v1  Acquiring lexical information is a complex pro...    cs
# 21441  1802.06895v1  There is a growing interest within the AI rese...    cs
# 22836  1708.02883v2  Consider a structured matrix factorization mod...  stat
# 19291   1304.3087v1  We start by defining an approach to non-monoto...    cs
# 19698   1109.5072v1  Today, available methods that assess AI system...    cs
#
#                                                    title  year  \
# 15106                                  Clinical TempEval  2014
# 12981  Smoothing proximal gradient method for general...  2010
# 7995   BreathRNNet: Breathing Based Authentication on...  2017
# 12133              A Quasi-isometric Embedding Algorithm  2017
# 29233  Facial Expression Recognition using Visual Sal...  2017
# ...                                                  ...   ...
# 14916  Using qualia information to identify lexical s...  2013
# 21441  Hierarchical Expertise-Level Modeling for User...  2018
# 22836  Maximum Volume Inscribed Ellipsoid: A New Simp...  2017
# 19291        Non-Monotonicity in Probabilistic Reasoning  2013
# 19698  Analysis of first prototype universal intellig...  2011
#
#                                                 keywords
# 15106  [currently, preparation, evaluation, identifyi...
# 12981  [estimating, dimensional, regression, regulari...
# 7995   [recurrent, promising, processing, application...
# 12133  [embedding, embedding, dimension, projection, ...
# 29233  [developed, convolutional, recognizing, expres...
# ...                                                  ...
# 14916  [acquiring, information, typically, approached...
# 21441  [community, autonomous, explaining, explanatio...
# 22836  [structured, factorization, restricted, struct...
# 19291  [monotonic, probabilistic, reasoning, monotoni...
# 19698  [available, empirical, techniques, performance...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15106    [currently, preparation, evaluation, identifyi...
# 12981    [estimating, dimensional, regression, regulari...
# 7995     [recurrent, promising, processing, application...
# 12133    [embedding, embedding, dimension, projection, ...
# 29233    [developed, convolutional, recognizing, expres...
#                                ...
# 12766    [frameworks, prevalence, frameworks, statesima...
# 3400     [technique, convolutional, transparent, visual...
# 26657    [invariance, community, primarily, rotations, ...
# 21751    [optimization, computationally, intensive, reg...
# 14       [environments, challenge, reinforcement, algor...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8857 words.
# Out of those 4505 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="15b0abba-e2d1-416a-abb4-c5a596d2fc3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15b0abba-e2d1-416a-abb4-c5a596d2fc3e")) {                    Plotly.newPlot(                        "15b0abba-e2d1-416a-abb4-c5a596d2fc3e",                        [{"x":["describing","currently","container","relations","preparation","identifying","narrative","recognising","evaluation","penalties","regression","efficient","demonstrated","generalized","dimensional","technique","motivating","estimating","structured","convergence","developing","overlapping","optimization","significantly","subgradient","smoothing","simulation","information","experiments","regularized","variables","challenging","efficiency","effective","structural","scalability","performance","resources","implementing","inferences","outperform","constrained","breathing","promising","applications","capabilities","processing","popularity","feasibility","unexplored","nonetheless","smartphone","increasing","analytics","authentication","conventional","acoustics","significant","sequential","investigate","recurrent","modelling","embedding","structure","algorithm","dimension","isometric","projection","exhibited","recognition","developed","expression","generalization","different","independently","respectively","confusion","convolutional","accuracies","prediction","expressions","recognizing","experiment","predicted","partially","backpropagation","demonstrating","effectively","selecting","supervision","complementing","sufficient","labelling","supervised","detection","attentive","knowledge","objectness","integration","attentional","regardless","descriptions","distribution","interactions","databases","isomorphic","mathematical","procedure","introduce","functions","unavailable","description","probability","partitioning","collections","classification","restricting","successful","explicitly","comparison","collision","benchmark","efficiently","corroborated","applicable","stochastic","contribution","framework","techniques","convolved","discriminative","parameters","processes","previously","generative","multivariate","methodology","distributions","continuous","exploiting","implement","leverages","approaches","advantage","algorithms","alignment","iterative","computation","accelerate","naturally","comparing","minimized","furthermore","recasting","perception","interfaces","addressing","rendering","consequence","operations","advancements","optimizer","introducing","scenarios","annotations","generates","interaction","occlusion","attention","simultaneously","attracting","conditional","difficult","demonstrate","limitations","potentially","frequency","synthesis","controllable","synthesized","incomplete","important","interpretable","modalities","resolution","photorealistic","synthesizes","potential","nonlinear","principle","extensive","variational","dirichlet","likelihood","integrating","conjugacy","classifiers","inference","computational","available"],"y":[32,51,4,91,8,90,9,2,239,7,120,405,97,75,183,230,2,56,97,116,59,23,289,268,1,20,79,711,610,38,129,275,131,224,67,42,905,55,29,11,92,73,2,110,435,30,270,24,21,6,10,5,92,16,18,115,2,221,64,135,136,53,90,356,827,63,1,49,7,377,197,49,101,764,24,97,12,367,22,224,46,46,79,50,54,17,32,123,40,42,5,75,13,199,377,12,383,5,50,10,11,30,233,68,55,1,56,103,355,217,6,66,178,12,20,471,6,68,70,138,4,232,164,3,57,111,59,554,386,4,103,248,110,105,112,11,81,114,122,86,69,28,421,84,608,60,67,132,23,50,76,7,178,1,31,19,27,10,23,80,7,7,59,97,60,61,83,40,169,105,7,82,149,541,51,44,64,44,7,15,33,359,37,45,114,3,8,143,54,68,177,43,16,58,38,0,128,204,287,293],"type":"bar"},{"x":["describing","currently","container","relations","preparation","identifying","narrative","recognis ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4505,), (4505, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8258333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Goal</span> <span style=''>Spaces</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058822);'>Intrinsically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Motivated</span> <span style=''>Goal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.5294117647058822);'>Intrinsically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>goal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>enable</span> <span style=''>machines</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>repertoires</span> <span style=''>of</span> <span style=''>policies</span> <span style=''>that</span> <span style=''>produce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diversity</span> <span style=''>of</span> <span style=''>effects</span> <span style=''>in</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.46218487394957974);'>environments</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>real</span> <span style=''>world</span> <span style=''>robots</span> <span style=''>to</span> <span style=''>acquire</span> <span style=''>skills</span> <span style=''>such</span> <span style=''>as</span> <span style=''>tool</span> <span style=''>use</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3296703296703297);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>state</span> <span style=''>and</span> <span style=''>action</span> <span style=''>spaces</span> <span style=''>However</span> <span style=''>they</span> <span style=''>have</span> <span style=''>so</span> <span style=''>far</span> <span style=''>assumed</span> <span style=''>that</span> <span style=''>self</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>goals</span> <span style=''>are</span> <span style=''>sampled</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineered</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>limiting</span> <span style=''>their</span> <span style=''>autonomy</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3727810650887573);'>representation</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>an</span> <span style=''>adequate</span> <span style=''>goal</span> <span style=''>space</span> <span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developmental</span> <span style=''>2</span> <span style=''>stage</span> <span style=''>approach</span> <span style=''>first</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5454545454545454);'>perceptual</span> <span style=''>learning</span> <span style=''>stage</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Gap</span> <span style=''>Safe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>screening</span> <span style=''>rules</span> <span style=''>for</span> <span style=''>sparsity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enforcing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalties</span> <br/><br/><span style=''>In</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>settings</span> <span style=''>sparsity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enforcing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalties</span> <span style=''>have</span> <span style=''>proved</span> <span style=''>useful</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularize</span> <span style=''>the</span> <span style=''>data</span> <span style=''>fitting</span> <span style=''>term</span> <span style=''>A</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>screening</span> <span style=''>rules</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>ignore</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leveraging</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>sparsity</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consequently</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>faster</span> <span style=''>solvers</span> <span style=''>When</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>not</span> <span style=''>to</span> <span style=''>discard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>wrongly</span> <span style=''>the</span> <span style=''>rules</span> <span style=''>are</span> <span style=''>said</span> <span style=''>to</span> <span style=''>be</span> <span style=''>safe</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>unifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>linear</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>with</span> <span style=''>standard</span> <span style=''>sparsity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enforcing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalties</span> <span style=''>such</span> <span style=''>as</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>or</span> <span style=''>ell</span> <span style=''>1ell</span> <span style=''>2</span> <span style=''>norms</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>allows</span> <span style=''>to</span> <span style=''>discard</span> <span style=''>safely</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Formulation</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reduction</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Decision</span> <span style=''>Model</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>QMRDT</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>for</span> <span style=''>the</span> <span style=''>domain</span> <span style=''>of</span> <span style=''>internal</span> <span style=''>medicine</span> <span style=''>to</span> <span style=''>include</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decisions</span> <span style=''>about</span> <span style='background-color:rgba(255, 0, 0, 0.36000000000000004);'>treatments</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>how</span> <span style=''>we</span> <span style=''>can</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>comprehensive</span> <span style=''>decision</span> <span style=''>model</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>a</span> <span style=''>simpler</span> <span style=''>decision</span> <span style=''>model</span> <span style=''>for</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>patient</span> <span style=''>In</span> <span style=''>so</span> <span style=''>doing</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.32038834951456313);'>transform</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>to</span> <span style=''>that</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>narrowing</span> <span style=''>of</span> <span style=''>a</span> <span style=''>larger</span> <span style=''>problem</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Pruning</span> <span style=''>Random</span> <span style=''>Forests</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>on</span> <span style=''>a</span> <span style=''>Budget</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>prune</span> <span style=''>a</span> <span style=''>random</span> <span style=''>forest</span> <span style=''>(RF)</span> <span style=''>for</span> <span style=''>resource</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>We</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>a</span> <span style=''>RF</span> <span style=''>and</span> <span style=''>then</span> <span style=''>prune</span> <span style=''>it</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>expected</span> <span style=''>feature</span> <span style=''>cost</span> <span style=''>accuracy</span> <span style=''>We</span> <span style=''>pose</span> <span style=''>pruning</span> <span style=''>RFs</span> <span style=''>as</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>0</span> <span style=''>1</span> <span style=''>integer</span> <span style=''>program</span> <span style=''>with</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encourages</span> <span style=''>feature</span> <span style=''>re</span> <span style=''>use</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>total</span> <span style=''>unimodularity</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>set</span> <span style=''>to</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>LP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxation</span> <span style=''>solves</span> <span style=''>the</span> <span style=''>original</span> <span style=''>integer</span> <span style=''>program</span> <span style=''>We</span> <span style=''>then</span> <span style=''>exploit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connections</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>and</span> <span style=''>develop</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>primal</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>scalable</span> <span style=''>to</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>our</span> <span style=''>bottom</span> <span style=''>up</span> <span style=''>approach</span> <span style=''>which</span> <span style=''>benefits</span> <span style=''>from</span> <span style=''>good</span> <span style=''>RF</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initialization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>top</span> <span style=''>down</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquiring</span> <span style=''>features</span> <span style=''>based</span> <span style=''>on</span> <span style=''>their</span> <span style=''>utility</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09743774810537711)
# 	challenging (0.09924215084806928)
# 	segmentation (0.06928906531937928)
# 	knowledge (0.13821725009022015)
# 	information (0.2565860700108264)
# 	experimental (0.14435221941537352)
# 	detection (0.13605196679898954)
# 	different (0.2757127390833634)
# 	convolutional (0.1324431613136052)
# 	recognition (0.13605196679898954)
#
# Some Statistics words are:
# 	variables (0.13208477082306555)
# 	distribution (0.1759487432232627)
# 	stochastic (0.13454903893543618)
# 	theoretical (0.15179891572203055)
# 	algorithm (0.3952686052242484)
# 	statistical (0.15672745194677182)
# 	estimation (0.17299162148841793)
# 	inference (0.18334154756037457)
# 	dimensional (0.17890586495810745)
# 	regression (0.1680630852636767)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="270ecf35-7b71-43ad-9e1f-b081b1eafd6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("270ecf35-7b71-43ad-9e1f-b081b1eafd6f")) {                    Plotly.newPlot(                        "270ecf35-7b71-43ad-9e1f-b081b1eafd6f",                        [{"x":["describing","currently","container","relations","preparation","identifying","narrative","recognising","evaluation","penalties","regression","efficient","demonstrated","generalized","dimensional","technique","motivating","estimating","structured","convergence","developing","overlapping","optimization","significantly","subgradient","smoothing","simulation","information","experiments","regularized","variables","challenging","efficiency","effective","structural","scalability","performance","resources","implementing","inferences","outperform","constrained","breathing","promising","applications","capabilities","processing","popularity","feasibility","unexplored","nonetheless","smartphone","increasing","analytics","authentication","conventional","acoustics","significant","sequential","investigate","recurrent","modelling","embedding","structure","algorithm","dimension","isometric","projection","exhibited","recognition","developed","expression","generalization","different","independently","respectively","confusion","convolutional","accuracies","prediction","expressions","recognizing","experiment","predicted","partially","backpropagation","demonstrating","effectively","selecting","supervision","complementing","sufficient","labelling","supervised","detection","attentive","knowledge","objectness","integration","attentional","regardless","descriptions","distribution","interactions","databases","isomorphic","mathematical","procedure","introduce","functions","unavailable","description","probability","partitioning","collections","classification","restricting","successful","explicitly","comparison","collision","benchmark","efficiently","corroborated","applicable","stochastic","contribution","framework","techniques","convolved","discriminative","parameters","processes","previously","generative","multivariate","methodology","distributions","continuous","exploiting","implement","leverages","approaches","advantage","algorithms","alignment","iterative","computation","accelerate","naturally","comparing","minimized","furthermore","recasting","perception","interfaces","addressing","rendering","consequence","operations","advancements","optimizer","introducing","scenarios","annotations","generates","interaction","occlusion","attention","simultaneously","attracting","conditional","difficult","demonstrate","limitations","potentially","frequency","synthesis","controllable","synthesized","incomplete","important","interpretable","modalities","resolution","photorealistic","synthesizes","potential","nonlinear","principle","extensive","variational","dirichlet","likelihood","integrating","conjugacy","classifiers","inference","computational","available","extracting","consecutive","validation","microscopy","challenge","histology","predominant","literature","carcinoma","categories","boltzmann","resulting","alternative","restricted","distinguished","competitive","handwritten","unsupervised","automatically","unlabeled","presented","objective","additionally","dominance","mechanism","indicates","constraint","optimized","experimental","including","application","engineering","decomposition","evolutionary","solutions","population","instances","benchmarks","diversity","separately","extracted","classical","adaptively","reproducing","formulation","artificial","embeddings","implicitly","combinations","recursive","considering","quadratic","theoretical","generated","converges","favorable","activations","realizable","i ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	conjugacy
# 	triangular
# 	collinearity
# 	collapsed
# 	indiscriminate
# 	poisoning
# 	deflation
# 	electrocardiograms
# 	fibrillation
# 	prewhitening
# 	logitboost
# 	negativity
# 	parsimony
# 	formulates
# 	hypernetwork
# 	hypernetworks
# 	advantageously
# 	mcdiarmids
# 	cytometry
# 	borrowings
# Some words which never appear in Statistics papers:
# 	container
# 	narrative
# 	breathing
# 	smartphone
# 	authentication
# 	acoustics
# 	complementing
# 	attentive
# 	objectness
# 	corroborated
# 	histology
# 	carcinoma
# 	inputoutput
# 	superpixel
# 	continues
# 	superpixels
# 	subsystems
# 	bisimulation
# 	susceptibility
# 	legitimate

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.104144032283098e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7883333333333333
